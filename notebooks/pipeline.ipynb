# %%
import os, sys
os.chdir("..")          # if needed
sys.path.append(os.getcwd())

from src.pipeline.run_pipeline import main
main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       2 os.chdir("..")          # if needed
#       3 sys.path.append(os.getcwd())
# ----> 5 from src.pipeline.run_pipeline import main
#       6 main()
#
# ModuleNotFoundError: No module named 'src'

# %%
# %run ../src/pipeline/run_pipeline.py all
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/IPython/core/magics/execution.py:728, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     727     fpath = arg_lst[0]
# --> 728     filename = file_finder(fpath)
#     729 except IndexError as e:
#
# File /opt/conda/lib/python3.11/site-packages/IPython/utils/path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'../src/pipeline/run_pipeline.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('run', '../src/pipeline/run_pipeline.py all')
#
# ...
